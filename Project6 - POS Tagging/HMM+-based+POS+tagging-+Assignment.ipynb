# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from IPython.display import display

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# train - validation split =  95 - 5 
train_set, test_set = train_test_split(nltk_data,test_size=0.05,random_state=100)

# %%
# extracting (token,tag) tuples
taggedWords = [tup for sent in train_set for tup in sent]
print("List of training words")
print(len(taggedWords))

# extracting tokens
tokens = [pair[0] for pair in taggedWords]

# creating vocabulary
V = set(tokens)

# extracting all tags (unique)
T = set([pair[1] for pair in taggedWords])
# Out:
# List of training words
# 95949

# %%
## List of tags in the train set 
print(T)
# Out:
# {'.', 'ADJ', 'DET', 'X', 'CONJ', 'ADV', 'ADP', 'PRON', 'NUM', 'PRT', 'VERB', 'NOUN'}

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# creating T x V matrix to store all probabilities
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# function of emission probability
def WordGivenTag(word,tag,trainData = taggedWords):
    tagList = [pair for pair in trainData if pair[1] == tag] 
    tagCount = len(tagList)
    wordOccurWithTagCount = len([pair[0] for pair in tagList if pair[0] == word])
    
    return (wordOccurWithTagCount,tagCount)

# function of transition probability 
def T2GivenT1(t2,t1,trainData = taggedWords):
    tagList = [pair[1] for pair in trainData]
    count_t1 = len([tag for tag in tagList if tag == t1])
    count_t2_t1 = 0
    for index in range(len(tagList)-1):
        if(tagList[index] == t1 and tagList[index + 1] == t2):
            count_t2_t1 += 1
    return (count_t2_t1,count_t1)

# creating trandition matrix
transMatrix = np.zeros((len(T),len(T)),dtype="float32")
for i,t1 in enumerate(list(T)):
    for j,t2 in enumerate(list(T)):
        t2_t1 = T2GivenT1(t2,t1)
        transMatrix[i,j] = t2_t1[0]/t2_t1[1]
        
df = pd.DataFrame(transMatrix, columns = list(T), index=list(T))
df
# Out:
#              .       ADJ       DET         X      CONJ       ADV       ADP  \
# .     0.092923  0.043681  0.173558  0.026908  0.058032  0.052292  0.092206
# ADJ   0.063882  0.067158  0.004914  0.020311  0.016052  0.004914  0.078624
# DET   0.017913  0.204977  0.005771  0.045323  0.000481  0.012623  0.009618
# X     0.162831  0.016505  0.055229  0.074433  0.010316  0.025393  0.144898
# CONJ  0.035698  0.118683  0.118683  0.008809  0.000464  0.053778  0.053778
# ADV   0.135153  0.130160  0.069907  0.023302  0.006991  0.077230  0.119507
# ADP   0.039754  0.107389  0.323969  0.034984  0.000848  0.013357  0.017492
# PRON  0.040613  0.072031  0.009195  0.092720  0.004981  0.034100  0.023372
# NUM   0.118835  0.033571  0.003862  0.211824  0.013072  0.002674  0.035056
# PRT   0.043635  0.083661  0.101050  0.013123  0.002297  0.010171  0.019357
# VERB  0.034291  0.065640  0.133292  0.218438  0.005186  0.082050  0.091184
# NOUN  0.239951  0.012165  0.013363  0.028868  0.042921  0.016813  0.177058
#
#           PRON       NUM       PRT      VERB      NOUN
# .     0.065208  0.081353  0.002511  0.088708  0.222531
# ADJ   0.000491  0.020803  0.010156  0.011794  0.700901
# DET   0.003727  0.021640  0.000240  0.040394  0.637293
# X     0.055705  0.002857  0.184891  0.204571  0.062371
# CONJ  0.058414  0.042188  0.003709  0.155308  0.350487
# ADV   0.015646  0.031624  0.014314  0.344541  0.031624
# ADP   0.069119  0.061910  0.001484  0.008481  0.321213
# PRON  0.007663  0.007280  0.012261  0.484291  0.211494
# NUM   0.001485  0.184195  0.026144  0.016934  0.352347
# PRT   0.017717  0.056102  0.001969  0.405184  0.245735
# VERB  0.035916  0.022448  0.031427  0.168744  0.111386
# NOUN  0.004721  0.009550  0.043357  0.146955  0.264280

# %%
# Viterbi Heuristic
def VanillaViterbi(words, train_bag = taggedWords):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = df.loc['.', tag]
            else:
                transition_p = df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission = WordGivenTag(words[key], tag)
            emission_p = emission[0]/emission[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
taggedWords = [tup for sent in test_set for tup in sent]
untaggedWords = [tup[0] for sent in test_set for tup in sent]

vitterbi = VanillaViterbi(untaggedWords)
check = [i for i, j in zip(vitterbi, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbi)
accuracy
# Out:
# 0.9028982441294691

# %%
# List of incorrect tags - (Word, predicted tag, actual tag)

incorrect_tagged_words = [(a[0],a[1],b[1]) for a,b in zip(vitterbi,taggedWords) if a[1] != b[1]]
print(len(incorrect_tagged_words))
incorrect_tagged_words
# Out:
# 459
# [('book', 'NOUN', 'VERB'),
#  ('stocks', 'NOUN', 'ADV'),
#  ('up', 'PRT', 'ADP'),
#  ('over', 'ADP', 'PRT'),
#  ('ignored', '.', 'VERB'),
#  ('mine', 'NOUN', 'ADJ'),
#  ('Palestinian', 'ADJ', 'NOUN'),
#  ('first', 'ADJ', 'ADV'),
#  ('Preston', '.', 'NOUN'),
#  ('Birmingham', '.', 'NOUN'),
#  ('Ala', '.', 'NOUN'),
#  ('clamped', '.', 'VERB'),
#  ('ankle', '.', 'NOUN'),
#  ('third-largest', '.', 'ADJ'),
#  ('fifth-largest', '.', 'ADJ'),
#  ('Z.', '.', 'NOUN'),
#  ('Wick', '.', 'NOUN'),
#  ('89.7', '.', 'NUM'),
#  ('141.9', '.', 'NUM'),
#  ('94.8', '.', 'NUM'),
#  ('149.9', '.', 'NUM'),
#  ('argues', '.', 'VERB'),
#  ('Sit', '.', 'VERB'),
#  ('British', 'ADJ', 'NOUN'),
#  ('halt', 'NOUN', 'VERB'),
#  ('slides', 'NOUN', 'VERB'),
#  ('most', 'ADJ', 'ADV'),
#  ('athletic', '.', 'ADJ'),
#  ('to', 'PRT', 'ADJ'),
#  ('better', 'ADJ', 'ADV'),
#  ('illustrates', '.', 'VERB'),
#  ('attempt', 'VERB', 'NOUN'),
#  ('usurp', '.', 'VERB'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('609', '.', 'NUM'),
#  ('executive-office', '.', 'NOUN'),
#  ('administer', '.', 'VERB'),
#  ('disapproved', '.', 'VERB'),
#  ('*-58', '.', 'X'),
#  ('disapproval', '.', 'NOUN'),
#  ('accordance', '.', 'NOUN'),
#  ('applicable', '.', 'ADJ'),
#  ('Mead', '.', 'NOUN'),
#  ('Paper', '.', 'NOUN'),
#  ('Paper', '.', 'NOUN'),
#  ('Paper', '.', 'NOUN'),
#  ('Louisiana-Pacific', '.', 'NOUN'),
#  ('Five', '.', 'NUM'),
#  ('DeFazio', '.', 'NOUN'),
#  ('criteria', '.', 'NOUN'),
#  ('Proper', '.', 'ADJ'),
#  ('English', 'NOUN', 'ADJ'),
#  ('rounds', '.', 'NOUN'),
#  ('highest-pitched', '.', 'ADJ'),
#  ('descending', '.', 'VERB'),
#  ('as', 'ADP', 'ADV'),
#  ('62-year-old', '.', 'ADJ'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('forest-product', '.', 'NOUN'),
#  ('unsolicited', '.', 'ADJ'),
#  ('3.19', '.', 'NUM'),
#  ('bid', 'VERB', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('diversified', 'ADJ', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('impressive', '.', 'ADJ'),
#  ('issue', 'NOUN', 'VERB'),
#  ('29year', '.', 'ADJ'),
#  ('nine-month', '.', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('ECONOMIC', '.', 'ADJ'),
#  ('GROWTH', '.', 'NOUN'),
#  ('APPEARS', '.', 'VERB'),
#  ('off', 'PRT', 'ADP'),
#  ('that', 'ADP', 'DET'),
#  ('S.A', '.', 'NOUN'),
#  ('U.S.-Japanese', '.', 'ADJ'),
#  ('behemoth', '.', 'NOUN'),
#  ('*T*-174', '.', 'X'),
#  ('hotels', '.', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('*T*-175', '.', 'X'),
#  ('masters', '.', 'NOUN'),
#  ('Tiny', '.', 'NOUN'),
#  ('Tots', '.', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('past', 'ADJ', 'NOUN'),
#  ('Kelli', '.', 'NOUN'),
#  ('Green', '.', 'NOUN'),
#  ('senior', 'ADJ', 'NOUN'),
#  ('speculate', '.', 'VERB'),
#  ('yen-support', '.', 'ADJ'),
#  ('intervention', '.', 'NOUN'),
#  ('150.00', '.', 'NUM'),
#  ('excess', 'ADJ', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('smiles', '.', 'NOUN'),
#  ('Mont', '.', 'NOUN'),
#  ('exits', '.', 'NOUN'),
#  ('rebound', 'VERB', 'NOUN'),
#  ('pushes', '.', 'VERB'),
#  ('Left', '.', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('so', 'ADP', 'ADV'),
#  ('much', 'ADJ', 'ADV'),
#  ('Sandoz', '.', 'NOUN'),
#  ('preclinical', '.', 'ADJ'),
#  ('vague', '.', 'ADJ'),
#  ('mushy', '.', 'ADJ'),
#  ('that', 'DET', 'ADP'),
#  ('viewpoints', '.', 'NOUN'),
#  ('out', 'PRT', 'ADV'),
#  ('le', '.', 'DET'),
#  ('115', '.', 'NUM'),
#  ('genie', '.', 'NOUN'),
#  ('len', '.', 'NOUN'),
#  ("'s", 'VERB', 'PRT'),
#  ('foldability', '.', 'NOUN'),
#  ('inserted', '.', 'VERB'),
#  ('incisions', '.', 'NOUN'),
#  ('eye', '.', 'NOUN'),
#  ('care', 'VERB', 'NOUN'),
#  ('care', 'VERB', 'NOUN'),
#  ('clear', 'ADJ', 'VERB'),
#  ('ethanol', '.', 'NOUN'),
#  ('fuel', 'NOUN', 'VERB'),
#  ('fleet', '.', 'NOUN'),
#  ('Lucille', '.', 'NOUN'),
#  ('84-year-old', '.', 'ADJ'),
#  ('housewife', '.', 'NOUN'),
#  ('amazingly', '.', 'ADV'),
#  ('jolts', '.', 'NOUN'),
#  ('DISCOUNT', '.', 'NOUN'),
#  ('sight', '.', 'NOUN'),
#  ('*T*-178', '.', 'X'),
#  ('Kirkpatrick', '.', 'NOUN'),
#  ('*-154', '.', 'X'),
#  ('Sumitomo', '.', 'NOUN'),
#  ('Metal', '.', 'NOUN'),
#  ('692', '.', 'NUM'),
#  ('960', '.', 'NUM'),
#  ('individual', 'ADJ', 'NOUN'),
#  ('51.6', '.', 'NUM'),
#  ('readings', '.', 'NOUN'),
#  ('wrestling', '.', 'VERB'),
#  ('intelligent', '.', 'ADJ'),
#  ('insane', '.', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('tailor-made', '.', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('purhasing', '.', 'NOUN'),
#  ('report', 'VERB', 'NOUN'),
#  ('movies', '.', 'NOUN'),
#  ('Peck', '.', 'NOUN'),
#  ('marvelously', '.', 'ADV'),
#  ('loose', '.', 'ADJ'),
#  ('portrayal', '.', 'NOUN'),
#  ('work', 'VERB', 'NOUN'),
#  ('force', 'VERB', 'NOUN'),
#  ('Cataracts', '.', 'NOUN'),
#  ('refer', '.', 'VERB'),
#  ('clouding', '.', 'NOUN'),
#  ('eye', '.', 'NOUN'),
#  ("'s", 'VERB', 'PRT'),
#  ('*-107', '.', 'X'),
#  ('about', 'ADP', 'ADV'),
#  ('maturing', '.', 'VERB'),
#  ('up', 'ADV', 'PRT'),
#  ('filled', '.', 'VERB'),
#  ('solemn', '.', 'ADJ'),
#  ('intoxication', '.', 'NOUN'),
#  ('*T*-226', '.', 'X'),
#  ('intricate', '.', 'ADJ'),
#  ('ritual', '.', 'NOUN'),
#  ('faultlessly', '.', 'ADV'),
#  ('properties', '.', 'NOUN'),
#  ('Indexing', '.', 'NOUN'),
#  ('barometer', '.', 'NOUN'),
#  ('panic', 'NOUN', 'VERB'),
#  ('so', 'ADV', 'ADP'),
#  ('crying', '.', 'VERB'),
#  ('assistant', 'NOUN', 'ADJ'),
#  ('Ilminster', '.', 'NOUN'),
#  ('Somerset', '.', 'NOUN'),
#  ('following', 'NOUN', 'VERB'),
#  ('dust-up', '.', 'NOUN'),
#  ('attendance', '.', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('8.75', '.', 'NUM'),
#  ('shown', '.', 'VERB'),
#  ('Video', '.', 'NOUN'),
#  ('Tip', '.', 'NOUN'),
#  ('finest', '.', 'ADJ'),
#  ('472', '.', 'NUM'),
#  ('defeats', '.', 'VERB'),
#  ('inkling', '.', 'NOUN'),
#  ('that', 'DET', 'ADP'),
#  ('underprivileged', '.', 'ADJ'),
#  ('prosecutor', '.', 'NOUN'),
#  ('*T*-96', '.', 'X'),
#  ('alumni', '.', 'NOUN'),
#  ('cultivated', '.', 'VERB'),
#  ('much', 'ADJ', 'ADV'),
#  ('savvier', '.', 'ADJ'),
#  ('much', 'ADV', 'ADJ'),
#  ('burned', '.', 'VERB'),
#  ('wrath', '.', 'NOUN'),
#  ('Californian', '.', 'NOUN'),
#  ('Bolivia', '.', 'NOUN'),
#  ('broadened', '.', 'VERB'),
#  ('initiate', '.', 'NOUN'),
#  ('as', 'ADP', 'ADV'),
#  ('R.D.', '.', 'NOUN'),
#  ('Vos', '.', 'NOUN'),
#  ('N.Y', '.', 'NOUN'),
#  ('delayed', '.', 'VERB'),
#  ('as', 'ADP', 'ADV'),
#  ('Above', '.', 'ADP'),
#  ('confused', 'ADJ', 'VERB'),
#  ('around', 'ADP', 'PRT'),
#  ('accountants', '.', 'NOUN'),
#  ('blinks', '.', 'VERB'),
#  ('eye', '.', 'NOUN'),
#  ('bar', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('abortion-related', '.', 'ADJ'),
#  ("'s", 'PRT', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('further', 'ADJ', 'ADV'),
#  ('load', 'NOUN', 'VERB'),
#  ('dreamed', '.', 'VERB'),
#  ('up', 'ADV', 'PRT'),
#  ('improbable', '.', 'ADJ'),
#  ('shop', '.', 'NOUN'),
#  ('high-rise', '.', 'ADJ'),
#  ('help', 'VERB', 'NOUN'),
#  ('diagram', '.', 'NOUN'),
#  ('arrows', '.', 'NOUN'),
#  ('polystyrene', '.', 'NOUN'),
#  ('foam', '.', 'NOUN'),
#  ('polyproplene', '.', 'NOUN'),
#  ('polyester', '.', 'NOUN'),
#  ('plastic', 'ADJ', 'NOUN'),
#  ('non-biodegradable', '.', 'ADJ'),
#  ('over', 'ADP', 'PRT'),
#  ('seventh', '.', 'ADJ'),
#  ("'82", '.', 'NUM'),
#  ('115', '.', 'NUM'),
#  ('Researchers', '.', 'NOUN'),
#  ('American', 'ADJ', 'NOUN'),
#  ('closer', 'ADV', 'ADJ'),
#  ('unwilling', '.', 'ADJ'),
#  ('manpower', '.', 'NOUN'),
#  ('removing', '.', 'VERB'),
#  ('safeguarding', '.', 'VERB'),
#  ('Anku', '.', 'NOUN'),
#  ('Ketchum', '.', 'NOUN'),
#  ('Braun', '.', 'NOUN'),
#  ('investor-relations', '.', 'NOUN'),
#  ('marketing-communications', '.', 'NOUN'),
#  ('headed', '.', 'VERB'),
#  ('curbed', '.', 'VERB'),
#  ('index-fund', 'NOUN', 'ADJ'),
#  ('leveraging', '.', 'VERB'),
#  ('owning', '.', 'VERB'),
#  ('more', 'ADV', 'ADJ'),
#  ('own', 'ADJ', 'VERB'),
#  ('flirted', '.', 'VERB'),
#  ('charge', 'NOUN', 'VERB'),
#  ('American', 'ADJ', 'NOUN'),
#  ('matters', 'NOUN', 'VERB'),
#  ('fine', 'NOUN', 'ADV'),
#  ('chief', 'NOUN', 'ADJ'),
#  ('*-152', '.', 'X'),
#  ('father-in-law', '.', 'NOUN'),
#  ('Gardner', '.', 'NOUN'),
#  ('Hubbard', '.', 'NOUN'),
#  ('wealthy', '.', 'ADJ'),
#  ('well-connected', '.', 'ADJ'),
#  ('financing', 'VERB', 'NOUN'),
#  ('American', 'ADJ', 'NOUN'),
#  ('Moon', '.', 'NOUN'),
#  ('Landrieu', '.', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('cavernous', '.', 'ADJ'),
#  ('money-losing', '.', 'ADJ'),
#  ('benefits', 'NOUN', 'VERB'),
#  ('relevance', '.', 'NOUN'),
#  ('U.S.', 'NOUN', 'ADJ'),
#  ('143.93', '.', 'NUM'),
#  ('close', 'VERB', 'NOUN'),
#  ('143.08', '.', 'NUM'),
#  ('appeal', 'NOUN', 'VERB'),
#  ('cleanup', '.', 'NOUN'),
#  ('burn', '.', 'VERB'),
#  ('cleaner-burning', '.', 'ADJ'),
#  ('fuels', '.', 'NOUN'),
#  ('858,000', '.', 'NUM'),
#  ('overvalued', '.', 'VERB'),
#  ('Paris', '.', 'NOUN'),
#  ('Brussels', '.', 'NOUN'),
#  ('Milan', '.', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('discretion', '.', 'NOUN'),
#  ('select', '.', 'VERB'),
#  ('net', 'ADJ', 'NOUN'),
#  ('306', '.', 'NUM'),
#  ('unrestricted', '.', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('*-165', '.', 'X'),
#  ('firm', 'NOUN', 'ADJ'),
#  ('opening', 'VERB', 'NOUN'),
#  ('tempted', '.', 'VERB'),
#  ('less', 'ADV', 'ADJ'),
#  ('higher', 'ADJ', 'ADV'),
#  ('trading', 'NOUN', 'VERB'),
#  ('1980s', 'NUM', 'NOUN'),
#  ('glory', '.', 'NOUN'),
#  ('faded', '.', 'VERB'),
#  ('yellow', '.', 'ADJ'),
#  ('bricks', '.', 'NOUN'),
#  ('facade', '.', 'NOUN'),
#  ('record', 'NOUN', 'ADJ'),
#  ('550,000', '.', 'NUM'),
#  ('Four', '.', 'NUM'),
#  ('diagnosed', '.', 'VERB'),
#  ('half', 'DET', 'NOUN'),
#  ('27-year', '.', 'ADJ'),
#  ('information-services', '.', 'NOUN'),
#  ('Southeast', 'NOUN', 'ADJ'),
#  ('1997', '.', 'NUM'),
#  ('uses', 'VERB', 'NOUN'),
#  ('cancer-causing', '.', 'ADJ'),
#  ('outlawed', '.', 'VERB'),
#  ('stemmed', '.', 'VERB'),
#  ('post', 'VERB', 'NOUN'),
#  ('directorship', '.', 'NOUN'),
#  ('little', 'ADJ', 'ADV'),
#  ('more', 'ADJ', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('*T*-117', '.', 'X'),
#  ('uptick', 'NOUN', 'VERB'),
#  ('head', 'NOUN', 'ADJ'),
#  ('Silverman', '.', 'NOUN'),
#  ('insurance-company', '.', 'NOUN'),
#  ('comments', 'NOUN', 'VERB'),
#  ('increases', 'NOUN', 'VERB'),
#  ('jeopardy', '.', 'NOUN'),
#  ('NEW', '.', 'NOUN'),
#  ('ACCOUNT', '.', 'NOUN'),
#  ('14.75', '.', 'NUM'),
#  ('Chilver', '.', 'NOUN'),
#  ('63-year-old', '.', 'ADJ'),
#  ('English', 'ADJ', 'NOUN'),
#  ('Clays', '.', 'NOUN'),
#  ('CoreStates', '.', 'NOUN'),
#  ('Earle', '.', 'NOUN'),
#  ('Palmer', '.', 'NOUN'),
#  ('Spiro', '.', 'NOUN'),
#  ('account', 'VERB', 'NOUN'),
#  ('there', 'DET', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('escape', '.', 'NOUN'),
#  ('open', 'VERB', 'ADJ'),
#  ('drink', 'VERB', 'NOUN'),
#  ('insanity', '.', 'NOUN'),
#  ('heirs', '.', 'NOUN'),
#  ('Nylev', '.', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('malnutrition', '.', 'NOUN'),
#  ('chest', '.', 'NOUN'),
#  ('cardiovascular', '.', 'ADJ'),
#  ('infectious', '.', 'ADJ'),
#  ('aftereffects', '.', 'NOUN'),
#  ('assaults', '.', 'NOUN'),
#  ('*T*-91', '.', 'X'),
#  ('grandstander', '.', 'NOUN'),
#  ('luxury', '.', 'NOUN'),
#  ('879', '.', 'NUM'),
#  ('13.90', '.', 'NUM'),
#  ('guarantee', 'VERB', 'NOUN'),
#  ('operating', 'NOUN', 'VERB'),
#  ('shopped', '.', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('half', 'DET', 'NOUN'),
#  ('espouse', '.', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('one-third', 'NOUN', 'ADJ'),
#  ('finance', 'VERB', 'NOUN'),
#  ('deteriorating', '.', 'VERB'),
#  ('Anderson', '.', 'NOUN'),
#  ('59-year-old', '.', 'ADJ'),
#  ('fluctuations', '.', 'NOUN'),
#  ('heebie-jeebies', '.', 'NOUN'),
#  ('much', 'ADV', 'ADJ'),
#  ('point', 'VERB', 'NOUN'),
#  ('outlawing', '.', 'VERB'),
#  ('audit', 'VERB', 'NOUN'),
#  ('stand', 'VERB', 'NOUN'),
#  ('display', '.', 'VERB'),
#  ('projector', '.', 'NOUN'),
#  ('underline', '.', 'VERB'),
#  ('Old-House', '.', 'NOUN'),
#  ('publishing', 'VERB', 'NOUN'),
#  ('126,000', '.', 'NUM'),
#  ('all', 'DET', 'ADV'),
#  ('following', 'VERB', 'NOUN'),
#  ('round-trip', '.', 'ADJ'),
#  ('Trans', '.', 'NOUN'),
#  ('luxury', '.', 'NOUN'),
#  ('soaring', '.', 'VERB'),
#  ('reclaimed', '.', 'VERB'),
#  ('240-page', '.', 'ADJ'),
#  ('Iran-Contra', '.', 'NOUN'),
#  ('221.4', '.', 'NUM'),
#  ('Next', '.', 'ADJ'),
#  ('Philippine', '.', 'NOUN'),
#  ('launch', 'VERB', 'NOUN'),
#  ('capped', 'ADJ', 'VERB'),
#  ('Philippine', '.', 'ADJ'),
#  ('Corazon', '.', 'NOUN'),
#  ('Aquino', '.', 'NOUN'),
#  ('the', 'DET', 'NOUN'),
#  ('midyear', '.', 'NOUN'),
#  ('Spending', '.', 'NOUN'),
#  ('nonresidential', '.', 'ADJ'),
#  ('off', 'PRT', 'ADJ'),
#  ('99.1', '.', 'NUM'),
#  ('awaits', '.', 'VERB'),
#  ('point', 'NOUN', 'VERB'),
#  ('Aerospace', '.', 'NOUN'),
#  ('sagged', '.', 'VERB'),
#  ('B-1B', 'ADJ', 'NOUN'),
#  ('bombers', '.', 'NOUN'),
#  ('out', 'PRT', 'ADP'),
#  ('half', 'NOUN', 'DET'),
#  ('88.32', '.', 'NUM'),
#  ('618.1', '.', 'NUM'),
#  ('77.6', '.', 'NUM'),
#  ('earlier', 'ADV', 'ADJ'),
#  ('12.52', '.', 'NUM'),
#  ('11.95', '.', 'NUM'),
#  ('shipboard', '.', 'NOUN'),
#  ('next', 'ADP', 'ADJ'),
#  ('Soviet', 'ADJ', 'NOUN'),
#  ('off', 'PRT', 'ADP'),
#  ('Malta', '.', 'NOUN'),
#  ('NCNB', '.', 'NOUN'),
#  ('Connections', '.', 'NOUN'),
#  ('adults', '.', 'NOUN'),
#  ('broadly', '.', 'ADV'),
#  ('construed', '.', 'VERB'),
#  ('emasculate', '.', 'VERB'),
#  ('swallow', '.', 'VERB'),
#  ('contrary', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NUM')]

# %% [markdown]
# ### Solve the problem of unknown words

# %% [markdown]
# #### Modification 1 -  using transition probability incase of zero emission probability

# %%
# Viterbi Heuristic
def VitterbiMod(words, train_bag = taggedWords):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        trans_p = [] 
        for tag in T:
            if key == 0:
                transition_p = df.loc['.', tag]
            else:
                transition_p = df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission = WordGivenTag(words[key], tag)
            emission_p = emission[0]/emission[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            trans_p.append(transition_p)
            
        pmax = max(p)
        if pmax > 0 :
            # getting state for which probability is maximum
            state_max = T[p.index(pmax)]
        else:
            pmax = max(trans_p)
            state_max = T[trans_p.index(pmax)]
            
        state.append(state_max)
    return list(zip(words, state))

# %%
# checking the accuracy
vitterbiMod = VitterbiMod(untaggedWords)
check = [i for i, j in zip(vitterbiMod, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbiMod)
accuracy
# Out:
# 0.9331499894224666

# %% [markdown]
# #### Accuracy increased by ~ 3% compared to valilla viterbi

# %%
# List of incorrect tags - (Word, predicted tag, actual tag) after first modification

incorrect_tagged_words = [(a[0],a[1],b[1]) for a,b in zip(vitterbiMod,taggedWords) if a[1] != b[1]]
print(len(incorrect_tagged_words))
incorrect_tagged_words
# Out:
# 316
# [('book', 'NOUN', 'VERB'),
#  ('stocks', 'NOUN', 'ADV'),
#  ('up', 'PRT', 'ADP'),
#  ('over', 'ADP', 'PRT'),
#  ('mine', 'NOUN', 'ADJ'),
#  ('Palestinian', 'ADJ', 'NOUN'),
#  ('first', 'ADJ', 'ADV'),
#  ('clamped', 'X', 'VERB'),
#  ('ankle', 'VERB', 'NOUN'),
#  ('third-largest', 'NOUN', 'ADJ'),
#  ('fifth-largest', 'NOUN', 'ADJ'),
#  ('89.7', 'NOUN', 'NUM'),
#  ('141.9', 'NOUN', 'NUM'),
#  ('94.8', 'NOUN', 'NUM'),
#  ('149.9', 'NOUN', 'NUM'),
#  ('British', 'ADJ', 'NOUN'),
#  ('halt', 'NOUN', 'VERB'),
#  ('slides', 'NOUN', 'VERB'),
#  ('most', 'ADJ', 'ADV'),
#  ('athletic', 'DET', 'ADJ'),
#  ('to', 'PRT', 'ADJ'),
#  ('better', 'ADJ', 'ADV'),
#  ('attempt', 'VERB', 'NOUN'),
#  ('609', 'NOUN', 'NUM'),
#  ('administer', 'NOUN', 'VERB'),
#  ('disapproved', 'X', 'VERB'),
#  ('*-58', 'VERB', 'X'),
#  ('disapproval', 'DET', 'NOUN'),
#  ('accordance', 'DET', 'NOUN'),
#  ('applicable', 'NOUN', 'ADJ'),
#  ('Five', 'NOUN', 'NUM'),
#  ('Proper', 'NOUN', 'ADJ'),
#  ('English', 'NOUN', 'ADJ'),
#  ('highest-pitched', 'NOUN', 'ADJ'),
#  ('descending', 'NOUN', 'VERB'),
#  ('as', 'ADP', 'ADV'),
#  ('62-year-old', 'NOUN', 'ADJ'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('unsolicited', 'VERB', 'ADJ'),
#  ('3.19', 'NOUN', 'NUM'),
#  ('bid', 'VERB', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('diversified', 'ADJ', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('impressive', 'DET', 'ADJ'),
#  ('issue', 'NOUN', 'VERB'),
#  ('29year', 'DET', 'ADJ'),
#  ('nine-month', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('ECONOMIC', 'NOUN', 'ADJ'),
#  ('APPEARS', 'NOUN', 'VERB'),
#  ('off', 'PRT', 'ADP'),
#  ('that', 'ADP', 'DET'),
#  ('U.S.-Japanese', 'NOUN', 'ADJ'),
#  ('*T*-174', 'NOUN', 'X'),
#  ('hotels', 'X', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('*T*-175', 'DET', 'X'),
#  ('masters', 'DET', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('past', 'ADJ', 'NOUN'),
#  ('Kelli', 'VERB', 'NOUN'),
#  ('Green', 'X', 'NOUN'),
#  ('senior', 'ADJ', 'NOUN'),
#  ('yen-support', 'NOUN', 'ADJ'),
#  ('150.00', 'NOUN', 'NUM'),
#  ('excess', 'ADJ', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('rebound', 'VERB', 'NOUN'),
#  ('pushes', 'X', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('so', 'ADP', 'ADV'),
#  ('much', 'ADJ', 'ADV'),
#  ('preclinical', 'X', 'ADJ'),
#  ('vague', 'NOUN', 'ADJ'),
#  ('mushy', 'NOUN', 'ADJ'),
#  ('that', 'DET', 'ADP'),
#  ('out', 'PRT', 'ADV'),
#  ('le', 'NOUN', 'DET'),
#  ('115', 'NOUN', 'NUM'),
#  ('back', 'PRT', 'ADV'),
#  ('foldability', 'VERB', 'NOUN'),
#  ('inserted', 'X', 'VERB'),
#  ('care', 'VERB', 'NOUN'),
#  ('care', 'VERB', 'NOUN'),
#  ('clear', 'ADJ', 'VERB'),
#  ('fuel', 'NOUN', 'VERB'),
#  ('84-year-old', 'NOUN', 'ADJ'),
#  ('amazingly', 'X', 'ADV'),
#  ('sight', 'DET', 'NOUN'),
#  ('*T*-178', 'NOUN', 'X'),
#  ('692', 'VERB', 'NUM'),
#  ('960', 'VERB', 'NUM'),
#  ('individual', 'ADJ', 'NOUN'),
#  ('51.6', 'VERB', 'NUM'),
#  ('readings', 'DET', 'NOUN'),
#  ('wrestling', 'X', 'VERB'),
#  ('intelligent', 'VERB', 'ADJ'),
#  ('insane', 'VERB', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('tailor-made', 'X', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('report', 'VERB', 'NOUN'),
#  ('marvelously', 'NOUN', 'ADV'),
#  ('loose', 'NOUN', 'ADJ'),
#  ('work', 'VERB', 'NOUN'),
#  ('force', 'VERB', 'NOUN'),
#  ('refer', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('maturing', 'DET', 'VERB'),
#  ('up', 'ADV', 'PRT'),
#  ('filled', 'NOUN', 'VERB'),
#  ('solemn', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('*T*-226', 'DET', 'X'),
#  ('intricate', 'DET', 'ADJ'),
#  ('faultlessly', 'NOUN', 'ADV'),
#  ('panic', 'NOUN', 'VERB'),
#  ('so', 'ADV', 'ADP'),
#  ('crying', 'NOUN', 'VERB'),
#  ('assistant', 'NOUN', 'ADJ'),
#  ('Ilminster', 'DET', 'NOUN'),
#  ('following', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('8.75', 'VERB', 'NUM'),
#  ('shown', 'X', 'VERB'),
#  ('finest', 'VERB', 'ADJ'),
#  ('472', 'NOUN', 'NUM'),
#  ('underprivileged', 'NOUN', 'ADJ'),
#  ('*T*-96', 'VERB', 'X'),
#  ('alumni', 'VERB', 'NOUN'),
#  ('cultivated', 'X', 'VERB'),
#  ('much', 'ADJ', 'ADV'),
#  ('savvier', 'NOUN', 'ADJ'),
#  ('much', 'ADV', 'ADJ'),
#  ('burned', 'X', 'VERB'),
#  ('wrath', 'VERB', 'NOUN'),
#  ('Bolivia', 'X', 'NOUN'),
#  ('as', 'ADP', 'ADV'),
#  ('delayed', 'X', 'VERB'),
#  ('as', 'ADP', 'ADV'),
#  ('Above', 'NOUN', 'ADP'),
#  ('confused', 'ADJ', 'VERB'),
#  ('around', 'ADP', 'PRT'),
#  ('blinks', 'NOUN', 'VERB'),
#  ('bar', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('abortion-related', 'X', 'ADJ'),
#  ("'s", 'PRT', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('further', 'ADJ', 'ADV'),
#  ('load', 'NOUN', 'VERB'),
#  ('dreamed', 'NOUN', 'VERB'),
#  ('improbable', 'VERB', 'ADJ'),
#  ('shop', 'VERB', 'NOUN'),
#  ('high-rise', 'NOUN', 'ADJ'),
#  ('help', 'VERB', 'NOUN'),
#  ('arrows', 'DET', 'NOUN'),
#  ('polystyrene', 'VERB', 'NOUN'),
#  ('foam', 'X', 'NOUN'),
#  ('plastic', 'ADJ', 'NOUN'),
#  ('non-biodegradable', 'X', 'ADJ'),
#  ('over', 'ADP', 'PRT'),
#  ('seventh', 'VERB', 'ADJ'),
#  ('principal', 'ADJ', 'NOUN'),
#  ("'82", 'NOUN', 'NUM'),
#  ('115', 'NOUN', 'NUM'),
#  ('American', 'ADJ', 'NOUN'),
#  ('closer', 'ADV', 'ADJ'),
#  ('unwilling', 'VERB', 'ADJ'),
#  ('Braun', 'X', 'NOUN'),
#  ('headed', 'NOUN', 'VERB'),
#  ('index-fund', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('own', 'ADJ', 'VERB'),
#  ('flirted', 'X', 'VERB'),
#  ('charge', 'NOUN', 'VERB'),
#  ('American', 'ADJ', 'NOUN'),
#  ('matters', 'NOUN', 'VERB'),
#  ('fine', 'NOUN', 'ADV'),
#  ('chief', 'NOUN', 'ADJ'),
#  ('father-in-law', 'VERB', 'NOUN'),
#  ('wealthy', 'NOUN', 'ADJ'),
#  ('well-connected', 'NOUN', 'ADJ'),
#  ('financing', 'VERB', 'NOUN'),
#  ('American', 'ADJ', 'NOUN'),
#  ('Moon', 'VERB', 'NOUN'),
#  ('Landrieu', 'X', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('cavernous', 'VERB', 'ADJ'),
#  ('money-losing', 'NOUN', 'ADJ'),
#  ('benefits', 'NOUN', 'VERB'),
#  ('U.S.', 'NOUN', 'ADJ'),
#  ('143.93', 'DET', 'NUM'),
#  ('close', 'VERB', 'NOUN'),
#  ('143.08', 'DET', 'NUM'),
#  ('appeal', 'NOUN', 'VERB'),
#  ('burn', 'NOUN', 'VERB'),
#  ('cleaner-burning', 'NOUN', 'ADJ'),
#  ('858,000', 'DET', 'NUM'),
#  ('overvalued', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('net', 'ADJ', 'NOUN'),
#  ('306', 'NOUN', 'NUM'),
#  ('unrestricted', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('firm', 'NOUN', 'ADJ'),
#  ('opening', 'VERB', 'NOUN'),
#  ('less', 'ADV', 'ADJ'),
#  ('higher', 'ADJ', 'ADV'),
#  ('trading', 'NOUN', 'VERB'),
#  ('1980s', 'NUM', 'NOUN'),
#  ('glory', 'VERB', 'NOUN'),
#  ('faded', 'X', 'VERB'),
#  ('yellow', 'NOUN', 'ADJ'),
#  ('record', 'NOUN', 'ADJ'),
#  ('550,000', 'NOUN', 'NUM'),
#  ('Four', 'NOUN', 'NUM'),
#  ('half', 'DET', 'NOUN'),
#  ('27-year', 'NOUN', 'ADJ'),
#  ('Southeast', 'NOUN', 'ADJ'),
#  ('1997', 'DET', 'NUM'),
#  ('uses', 'VERB', 'NOUN'),
#  ('cancer-causing', 'DET', 'ADJ'),
#  ('outlawed', 'X', 'VERB'),
#  ('stemmed', 'NOUN', 'VERB'),
#  ('post', 'VERB', 'NOUN'),
#  ('little', 'ADJ', 'ADV'),
#  ('more', 'ADJ', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('*T*-117', 'DET', 'X'),
#  ('uptick', 'NOUN', 'VERB'),
#  ('head', 'NOUN', 'ADJ'),
#  ('comments', 'NOUN', 'VERB'),
#  ('increases', 'NOUN', 'VERB'),
#  ('jeopardy', 'DET', 'NOUN'),
#  ('14.75', 'NOUN', 'NUM'),
#  ('63-year-old', 'NOUN', 'ADJ'),
#  ('English', 'ADJ', 'NOUN'),
#  ('Earle', 'X', 'NOUN'),
#  ('Palmer', 'VERB', 'NOUN'),
#  ('account', 'VERB', 'NOUN'),
#  ('there', 'DET', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('escape', 'DET', 'NOUN'),
#  ('open', 'VERB', 'ADJ'),
#  ('drink', 'VERB', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('malnutrition', 'DET', 'NOUN'),
#  ('cardiovascular', 'NOUN', 'ADJ'),
#  ('infectious', 'NOUN', 'ADJ'),
#  ('assaults', 'DET', 'NOUN'),
#  ('*T*-91', 'VERB', 'X'),
#  ('879', 'DET', 'NUM'),
#  ('13.90', 'NOUN', 'NUM'),
#  ('guarantee', 'VERB', 'NOUN'),
#  ('operating', 'NOUN', 'VERB'),
#  ('shopped', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('half', 'DET', 'NOUN'),
#  ('espouse', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('one-third', 'NOUN', 'ADJ'),
#  ('finance', 'VERB', 'NOUN'),
#  ('deteriorating', 'DET', 'VERB'),
#  ('59-year-old', 'NOUN', 'ADJ'),
#  ('much', 'ADV', 'ADJ'),
#  ('point', 'VERB', 'NOUN'),
#  ('audit', 'VERB', 'NOUN'),
#  ('stand', 'VERB', 'NOUN'),
#  ('underline', 'NOUN', 'VERB'),
#  ('publishing', 'VERB', 'NOUN'),
#  ('126,000', 'NOUN', 'NUM'),
#  ('all', 'DET', 'ADV'),
#  ('following', 'VERB', 'NOUN'),
#  ('round-trip', 'NOUN', 'ADJ'),
#  ('Trans', 'DET', 'NOUN'),
#  ('soaring', 'NOUN', 'VERB'),
#  ('reclaimed', 'NOUN', 'VERB'),
#  ('240-page', 'VERB', 'ADJ'),
#  ('report', 'VERB', 'NOUN'),
#  ('221.4', 'NOUN', 'NUM'),
#  ('Next', 'NOUN', 'ADJ'),
#  ('launch', 'VERB', 'NOUN'),
#  ('capped', 'ADJ', 'VERB'),
#  ('Philippine', 'DET', 'ADJ'),
#  ('the', 'DET', 'NOUN'),
#  ('midyear', 'DET', 'NOUN'),
#  ('nonresidential', 'NOUN', 'ADJ'),
#  ('off', 'PRT', 'ADJ'),
#  ('99.1', 'NOUN', 'NUM'),
#  ('awaits', 'NOUN', 'VERB'),
#  ('point', 'NOUN', 'VERB'),
#  ('sagged', 'NOUN', 'VERB'),
#  ('B-1B', 'ADJ', 'NOUN'),
#  ('out', 'PRT', 'ADP'),
#  ('half', 'NOUN', 'DET'),
#  ('88.32', 'VERB', 'NUM'),
#  ('618.1', 'NOUN', 'NUM'),
#  ('77.6', 'DET', 'NUM'),
#  ('earlier', 'ADV', 'ADJ'),
#  ('12.52', 'NOUN', 'NUM'),
#  ('11.95', 'NOUN', 'NUM'),
#  ('next', 'ADP', 'ADJ'),
#  ('Soviet', 'ADJ', 'NOUN'),
#  ('off', 'PRT', 'ADP'),
#  ('Malta', 'VERB', 'NOUN'),
#  ('broadly', 'VERB', 'ADV'),
#  ('construed', 'X', 'VERB'),
#  ('emasculate', 'X', 'VERB'),
#  ('swallow', 'NOUN', 'VERB'),
#  ('contrary', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NUM')]

# %% [markdown]
# #### Modification 2 -  using a backoff tagger
#
# Using a backoff tagger incase of an unknown word.
# Here we are using regex tagger

# %%
patterns = [
    (r'[\w+]+ing$', 'VERB'),              # gerund
    (r'.*ed$', 'VERB'),               # past tense
    (r'.*es$', 'VERB'),               # 3rd singular present
    (r'.*\'s$', 'NOUN'),              # possessive nouns
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'\*T?\*?-[0-9]+$', 'X'),        # X
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'), # cardinal numbers
    (r'.*', 'NOUN')                    # nouns
]
rule_based_tagger = nltk.RegexpTagger(patterns)

# %%
def VitterbiMod2(words,train_bag = taggedWords):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = df.loc['.', tag]
            else:
                transition_p = df.loc[state[-1], tag]
               
            emission = WordGivenTag(words[key], tag)
            emission_p = emission[0]/emission[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        state_max = rule_based_tagger.tag([word])[0][1]
        
        if pmax > 0:
          if state_max != "X":
            state_max = T[p.index(pmax)]  
        state.append(state_max)
    return list(zip(words, state))

# %%
# Testing of Modification 2

vitterbiMod2 = VitterbiMod2(untaggedWords)
check = [i for i, j in zip(vitterbiMod2, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbiMod2)
accuracy
# Out:
# 0.9494393907340808

# %% [markdown]
# #### Accuracy increased by ~ 5% compared to vanilla viterbi

# %%
# List of incorrect tags - (Word, predicted tag, actual tag)

incorrect_tagged_words = [(a[0],a[1],b[1]) for a,b in zip(vitterbiMod2,taggedWords) if a[1] != b[1]]
print(len(incorrect_tagged_words))
incorrect_tagged_words
# Out:
# 239
# [('book', 'NOUN', 'VERB'),
#  ('stocks', 'NOUN', 'ADV'),
#  ('up', 'PRT', 'ADP'),
#  ('over', 'ADP', 'PRT'),
#  ('mine', 'NOUN', 'ADJ'),
#  ('Palestinian', 'ADJ', 'NOUN'),
#  ('first', 'ADJ', 'ADV'),
#  ('third-largest', 'NOUN', 'ADJ'),
#  ('fifth-largest', 'NOUN', 'ADJ'),
#  ('Sit', 'NOUN', 'VERB'),
#  ('down', 'ADP', 'ADV'),
#  ('British', 'ADJ', 'NOUN'),
#  ('halt', 'NOUN', 'VERB'),
#  ('slides', 'NOUN', 'VERB'),
#  ('most', 'ADJ', 'ADV'),
#  ('athletic', 'NOUN', 'ADJ'),
#  ('to', 'PRT', 'ADJ'),
#  ('better', 'ADJ', 'ADV'),
#  ('attempt', 'VERB', 'NOUN'),
#  ('usurp', 'NOUN', 'VERB'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('administer', 'NOUN', 'VERB'),
#  ('applicable', 'NOUN', 'ADJ'),
#  ('Five', 'NOUN', 'NUM'),
#  ('Proper', 'NOUN', 'ADJ'),
#  ('English', 'NOUN', 'ADJ'),
#  ('highest-pitched', 'VERB', 'ADJ'),
#  ('as', 'ADP', 'ADV'),
#  ('62-year-old', 'NOUN', 'ADJ'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('unsolicited', 'VERB', 'ADJ'),
#  ('bid', 'VERB', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('diversified', 'ADJ', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('impressive', 'NOUN', 'ADJ'),
#  ('issue', 'NOUN', 'VERB'),
#  ('29year', 'NOUN', 'ADJ'),
#  ('nine-month', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('ECONOMIC', 'NOUN', 'ADJ'),
#  ('APPEARS', 'NOUN', 'VERB'),
#  ('off', 'PRT', 'ADP'),
#  ('that', 'ADP', 'DET'),
#  ('U.S.-Japanese', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('up', 'ADV', 'ADP'),
#  ('past', 'ADJ', 'NOUN'),
#  ('senior', 'ADJ', 'NOUN'),
#  ('speculate', 'NOUN', 'VERB'),
#  ('yen-support', 'NOUN', 'ADJ'),
#  ('excess', 'ADJ', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('smiles', 'VERB', 'NOUN'),
#  ('rebound', 'VERB', 'NOUN'),
#  ('Left', 'NOUN', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('so', 'ADP', 'ADV'),
#  ('much', 'ADJ', 'ADV'),
#  ('preclinical', 'NOUN', 'ADJ'),
#  ('vague', 'NOUN', 'ADJ'),
#  ('mushy', 'NOUN', 'ADJ'),
#  ('that', 'DET', 'ADP'),
#  ('out', 'PRT', 'ADV'),
#  ('le', 'NOUN', 'DET'),
#  ('back', 'PRT', 'ADV'),
#  ('care', 'VERB', 'NOUN'),
#  ('care', 'VERB', 'NOUN'),
#  ('clear', 'ADJ', 'VERB'),
#  ('fuel', 'NOUN', 'VERB'),
#  ('84-year-old', 'NOUN', 'ADJ'),
#  ('amazingly', 'NOUN', 'ADV'),
#  ('individual', 'ADJ', 'NOUN'),
#  ('intelligent', 'NOUN', 'ADJ'),
#  ('insane', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('tailor-made', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('purhasing', 'VERB', 'NOUN'),
#  ('report', 'VERB', 'NOUN'),
#  ('movies', 'VERB', 'NOUN'),
#  ('marvelously', 'NOUN', 'ADV'),
#  ('loose', 'NOUN', 'ADJ'),
#  ('work', 'VERB', 'NOUN'),
#  ('force', 'VERB', 'NOUN'),
#  ('refer', 'NOUN', 'VERB'),
#  ('clouding', 'VERB', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('solemn', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('intricate', 'NOUN', 'ADJ'),
#  ('faultlessly', 'NOUN', 'ADV'),
#  ('properties', 'VERB', 'NOUN'),
#  ('Indexing', 'VERB', 'NOUN'),
#  ('panic', 'NOUN', 'VERB'),
#  ('so', 'ADV', 'ADP'),
#  ('assistant', 'NOUN', 'ADJ'),
#  ('following', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('shown', 'NOUN', 'VERB'),
#  ('finest', 'NOUN', 'ADJ'),
#  ('defeats', 'NOUN', 'VERB'),
#  ('inkling', 'VERB', 'NOUN'),
#  ('underprivileged', 'VERB', 'ADJ'),
#  ('much', 'ADJ', 'ADV'),
#  ('savvier', 'NOUN', 'ADJ'),
#  ('much', 'ADV', 'ADJ'),
#  ('as', 'ADP', 'ADV'),
#  ('as', 'ADP', 'ADV'),
#  ('Above', 'NOUN', 'ADP'),
#  ('confused', 'ADJ', 'VERB'),
#  ('around', 'ADP', 'PRT'),
#  ('blinks', 'NOUN', 'VERB'),
#  ('bar', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('abortion-related', 'VERB', 'ADJ'),
#  ("'s", 'PRT', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('further', 'ADJ', 'ADV'),
#  ('load', 'NOUN', 'VERB'),
#  ('up', 'ADV', 'PRT'),
#  ('improbable', 'NOUN', 'ADJ'),
#  ('high-rise', 'NOUN', 'ADJ'),
#  ('help', 'VERB', 'NOUN'),
#  ('plastic', 'ADJ', 'NOUN'),
#  ('non-biodegradable', 'NOUN', 'ADJ'),
#  ('over', 'ADP', 'PRT'),
#  ('seventh', 'NOUN', 'ADJ'),
#  ("'82", 'NOUN', 'NUM'),
#  ('American', 'ADJ', 'NOUN'),
#  ('closer', 'ADV', 'ADJ'),
#  ('unwilling', 'VERB', 'ADJ'),
#  ('index-fund', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('own', 'ADJ', 'VERB'),
#  ('charge', 'NOUN', 'VERB'),
#  ('American', 'ADJ', 'NOUN'),
#  ('matters', 'NOUN', 'VERB'),
#  ('fine', 'NOUN', 'ADV'),
#  ('chief', 'NOUN', 'ADJ'),
#  ('wealthy', 'NOUN', 'ADJ'),
#  ('well-connected', 'VERB', 'ADJ'),
#  ('financing', 'VERB', 'NOUN'),
#  ('American', 'ADJ', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('cavernous', 'NOUN', 'ADJ'),
#  ('money-losing', 'NOUN', 'ADJ'),
#  ('benefits', 'NOUN', 'VERB'),
#  ('U.S.', 'NOUN', 'ADJ'),
#  ('close', 'VERB', 'NOUN'),
#  ('appeal', 'NOUN', 'VERB'),
#  ('burn', 'NOUN', 'VERB'),
#  ('cleaner-burning', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('select', 'NOUN', 'VERB'),
#  ('net', 'ADJ', 'NOUN'),
#  ('unrestricted', 'VERB', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('firm', 'NOUN', 'ADJ'),
#  ('opening', 'VERB', 'NOUN'),
#  ('less', 'ADV', 'ADJ'),
#  ('higher', 'ADJ', 'ADV'),
#  ('trading', 'NOUN', 'VERB'),
#  ('1980s', 'NUM', 'NOUN'),
#  ('yellow', 'NOUN', 'ADJ'),
#  ('record', 'NOUN', 'ADJ'),
#  ('Four', 'NOUN', 'NUM'),
#  ('half', 'DET', 'NOUN'),
#  ('27-year', 'NOUN', 'ADJ'),
#  ('information-services', 'VERB', 'NOUN'),
#  ('Southeast', 'NOUN', 'ADJ'),
#  ('uses', 'VERB', 'NOUN'),
#  ('cancer-causing', 'NOUN', 'ADJ'),
#  ('post', 'VERB', 'NOUN'),
#  ('little', 'ADJ', 'ADV'),
#  ('more', 'ADJ', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('uptick', 'NOUN', 'VERB'),
#  ('head', 'NOUN', 'ADJ'),
#  ('comments', 'NOUN', 'VERB'),
#  ('increases', 'NOUN', 'VERB'),
#  ('63-year-old', 'NOUN', 'ADJ'),
#  ('English', 'ADJ', 'NOUN'),
#  ('CoreStates', 'VERB', 'NOUN'),
#  ('account', 'VERB', 'NOUN'),
#  ('there', 'DET', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('open', 'VERB', 'ADJ'),
#  ('drink', 'VERB', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('cardiovascular', 'NOUN', 'ADJ'),
#  ('infectious', 'NOUN', 'ADJ'),
#  ('guarantee', 'VERB', 'NOUN'),
#  ('operating', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('half', 'DET', 'NOUN'),
#  ('espouse', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('one-third', 'NOUN', 'ADJ'),
#  ('finance', 'VERB', 'NOUN'),
#  ('59-year-old', 'NOUN', 'ADJ'),
#  ('heebie-jeebies', 'VERB', 'NOUN'),
#  ('much', 'ADV', 'ADJ'),
#  ('point', 'VERB', 'NOUN'),
#  ('audit', 'VERB', 'NOUN'),
#  ('stand', 'VERB', 'NOUN'),
#  ('display', 'NOUN', 'VERB'),
#  ('underline', 'NOUN', 'VERB'),
#  ('publishing', 'VERB', 'NOUN'),
#  ('all', 'DET', 'ADV'),
#  ('following', 'VERB', 'NOUN'),
#  ('round-trip', 'NOUN', 'ADJ'),
#  ('240-page', 'NOUN', 'ADJ'),
#  ('Next', 'NOUN', 'ADJ'),
#  ('launch', 'VERB', 'NOUN'),
#  ('capped', 'ADJ', 'VERB'),
#  ('Philippine', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NOUN'),
#  ('Spending', 'VERB', 'NOUN'),
#  ('nonresidential', 'NOUN', 'ADJ'),
#  ('off', 'PRT', 'ADJ'),
#  ('awaits', 'NOUN', 'VERB'),
#  ('point', 'NOUN', 'VERB'),
#  ('B-1B', 'ADJ', 'NOUN'),
#  ('out', 'PRT', 'ADP'),
#  ('half', 'NOUN', 'DET'),
#  ('earlier', 'ADV', 'ADJ'),
#  ('next', 'ADP', 'ADJ'),
#  ('Soviet', 'ADJ', 'NOUN'),
#  ('off', 'PRT', 'ADP'),
#  ('broadly', 'NOUN', 'ADV'),
#  ('emasculate', 'NOUN', 'VERB'),
#  ('swallow', 'NOUN', 'VERB'),
#  ('contrary', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NUM')]

# %% [markdown]
# #### Modification 3 -  using a unigram tagger and regex tagger as backoff tagger

# %%
unigramTagger = nltk.UnigramTagger(train_set, backoff=rule_based_tagger)

# %%
def VitterbiMod3(words,train_bag = taggedWords):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = df.loc['.', tag]
            else:
                transition_p = df.loc[state[-1], tag]
               
            emission = WordGivenTag(words[key], tag)
            emission_p = emission[0]/emission[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        state_max = unigramTagger.tag([word])[0][1]
        
        if pmax > 0:
          if state_max != "X":
            state_max = T[p.index(pmax)]  
        state.append(state_max)
    return list(zip(words, state))

# %%
vitterbiMod3 = VitterbiMod3(untaggedWords)
check = [i for i, j in zip(vitterbiMod3, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbiMod3)
accuracy
# Out:
# 0.9494393907340808

# %% [markdown]
# #### Accuracy is still the same even if using unigram as compared to regex tagger

# %%
# List of incorrect tags - (Word, predicted tag, actual tag)

incorrect_tagged_words = [(a[0],a[1],b[1]) for a,b in zip(vitterbiMod3,taggedWords) if a[1] != b[1]]
print(len(incorrect_tagged_words))
incorrect_tagged_words
# Out:
# 239
# [('book', 'NOUN', 'VERB'),
#  ('stocks', 'NOUN', 'ADV'),
#  ('up', 'PRT', 'ADP'),
#  ('over', 'ADP', 'PRT'),
#  ('mine', 'NOUN', 'ADJ'),
#  ('Palestinian', 'ADJ', 'NOUN'),
#  ('first', 'ADJ', 'ADV'),
#  ('third-largest', 'NOUN', 'ADJ'),
#  ('fifth-largest', 'NOUN', 'ADJ'),
#  ('Sit', 'NOUN', 'VERB'),
#  ('down', 'ADP', 'ADV'),
#  ('British', 'ADJ', 'NOUN'),
#  ('halt', 'NOUN', 'VERB'),
#  ('slides', 'NOUN', 'VERB'),
#  ('most', 'ADJ', 'ADV'),
#  ('athletic', 'NOUN', 'ADJ'),
#  ('to', 'PRT', 'ADJ'),
#  ('better', 'ADJ', 'ADV'),
#  ('attempt', 'VERB', 'NOUN'),
#  ('usurp', 'NOUN', 'VERB'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('administer', 'NOUN', 'VERB'),
#  ('applicable', 'NOUN', 'ADJ'),
#  ('Five', 'NOUN', 'NUM'),
#  ('Proper', 'NOUN', 'ADJ'),
#  ('English', 'NOUN', 'ADJ'),
#  ('highest-pitched', 'VERB', 'ADJ'),
#  ('as', 'ADP', 'ADV'),
#  ('62-year-old', 'NOUN', 'ADJ'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('unsolicited', 'VERB', 'ADJ'),
#  ('bid', 'VERB', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('diversified', 'ADJ', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('impressive', 'NOUN', 'ADJ'),
#  ('issue', 'NOUN', 'VERB'),
#  ('29year', 'NOUN', 'ADJ'),
#  ('nine-month', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('ECONOMIC', 'NOUN', 'ADJ'),
#  ('APPEARS', 'NOUN', 'VERB'),
#  ('off', 'PRT', 'ADP'),
#  ('that', 'ADP', 'DET'),
#  ('U.S.-Japanese', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('up', 'ADV', 'ADP'),
#  ('past', 'ADJ', 'NOUN'),
#  ('senior', 'ADJ', 'NOUN'),
#  ('speculate', 'NOUN', 'VERB'),
#  ('yen-support', 'NOUN', 'ADJ'),
#  ('excess', 'ADJ', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('smiles', 'VERB', 'NOUN'),
#  ('rebound', 'VERB', 'NOUN'),
#  ('Left', 'NOUN', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('so', 'ADP', 'ADV'),
#  ('much', 'ADJ', 'ADV'),
#  ('preclinical', 'NOUN', 'ADJ'),
#  ('vague', 'NOUN', 'ADJ'),
#  ('mushy', 'NOUN', 'ADJ'),
#  ('that', 'DET', 'ADP'),
#  ('out', 'PRT', 'ADV'),
#  ('le', 'NOUN', 'DET'),
#  ('back', 'PRT', 'ADV'),
#  ('care', 'VERB', 'NOUN'),
#  ('care', 'VERB', 'NOUN'),
#  ('clear', 'ADJ', 'VERB'),
#  ('fuel', 'NOUN', 'VERB'),
#  ('84-year-old', 'NOUN', 'ADJ'),
#  ('amazingly', 'NOUN', 'ADV'),
#  ('individual', 'ADJ', 'NOUN'),
#  ('intelligent', 'NOUN', 'ADJ'),
#  ('insane', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('tailor-made', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('purhasing', 'VERB', 'NOUN'),
#  ('report', 'VERB', 'NOUN'),
#  ('movies', 'VERB', 'NOUN'),
#  ('marvelously', 'NOUN', 'ADV'),
#  ('loose', 'NOUN', 'ADJ'),
#  ('work', 'VERB', 'NOUN'),
#  ('force', 'VERB', 'NOUN'),
#  ('refer', 'NOUN', 'VERB'),
#  ('clouding', 'VERB', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('solemn', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('intricate', 'NOUN', 'ADJ'),
#  ('faultlessly', 'NOUN', 'ADV'),
#  ('properties', 'VERB', 'NOUN'),
#  ('Indexing', 'VERB', 'NOUN'),
#  ('panic', 'NOUN', 'VERB'),
#  ('so', 'ADV', 'ADP'),
#  ('assistant', 'NOUN', 'ADJ'),
#  ('following', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('shown', 'NOUN', 'VERB'),
#  ('finest', 'NOUN', 'ADJ'),
#  ('defeats', 'NOUN', 'VERB'),
#  ('inkling', 'VERB', 'NOUN'),
#  ('underprivileged', 'VERB', 'ADJ'),
#  ('much', 'ADJ', 'ADV'),
#  ('savvier', 'NOUN', 'ADJ'),
#  ('much', 'ADV', 'ADJ'),
#  ('as', 'ADP', 'ADV'),
#  ('as', 'ADP', 'ADV'),
#  ('Above', 'NOUN', 'ADP'),
#  ('confused', 'ADJ', 'VERB'),
#  ('around', 'ADP', 'PRT'),
#  ('blinks', 'NOUN', 'VERB'),
#  ('bar', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('abortion-related', 'VERB', 'ADJ'),
#  ("'s", 'PRT', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('further', 'ADJ', 'ADV'),
#  ('load', 'NOUN', 'VERB'),
#  ('up', 'ADV', 'PRT'),
#  ('improbable', 'NOUN', 'ADJ'),
#  ('high-rise', 'NOUN', 'ADJ'),
#  ('help', 'VERB', 'NOUN'),
#  ('plastic', 'ADJ', 'NOUN'),
#  ('non-biodegradable', 'NOUN', 'ADJ'),
#  ('over', 'ADP', 'PRT'),
#  ('seventh', 'NOUN', 'ADJ'),
#  ("'82", 'NOUN', 'NUM'),
#  ('American', 'ADJ', 'NOUN'),
#  ('closer', 'ADV', 'ADJ'),
#  ('unwilling', 'VERB', 'ADJ'),
#  ('index-fund', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('own', 'ADJ', 'VERB'),
#  ('charge', 'NOUN', 'VERB'),
#  ('American', 'ADJ', 'NOUN'),
#  ('matters', 'NOUN', 'VERB'),
#  ('fine', 'NOUN', 'ADV'),
#  ('chief', 'NOUN', 'ADJ'),
#  ('wealthy', 'NOUN', 'ADJ'),
#  ('well-connected', 'VERB', 'ADJ'),
#  ('financing', 'VERB', 'NOUN'),
#  ('American', 'ADJ', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('cavernous', 'NOUN', 'ADJ'),
#  ('money-losing', 'NOUN', 'ADJ'),
#  ('benefits', 'NOUN', 'VERB'),
#  ('U.S.', 'NOUN', 'ADJ'),
#  ('close', 'VERB', 'NOUN'),
#  ('appeal', 'NOUN', 'VERB'),
#  ('burn', 'NOUN', 'VERB'),
#  ('cleaner-burning', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('select', 'NOUN', 'VERB'),
#  ('net', 'ADJ', 'NOUN'),
#  ('unrestricted', 'VERB', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('firm', 'NOUN', 'ADJ'),
#  ('opening', 'VERB', 'NOUN'),
#  ('less', 'ADV', 'ADJ'),
#  ('higher', 'ADJ', 'ADV'),
#  ('trading', 'NOUN', 'VERB'),
#  ('1980s', 'NUM', 'NOUN'),
#  ('yellow', 'NOUN', 'ADJ'),
#  ('record', 'NOUN', 'ADJ'),
#  ('Four', 'NOUN', 'NUM'),
#  ('half', 'DET', 'NOUN'),
#  ('27-year', 'NOUN', 'ADJ'),
#  ('information-services', 'VERB', 'NOUN'),
#  ('Southeast', 'NOUN', 'ADJ'),
#  ('uses', 'VERB', 'NOUN'),
#  ('cancer-causing', 'NOUN', 'ADJ'),
#  ('post', 'VERB', 'NOUN'),
#  ('little', 'ADJ', 'ADV'),
#  ('more', 'ADJ', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('uptick', 'NOUN', 'VERB'),
#  ('head', 'NOUN', 'ADJ'),
#  ('comments', 'NOUN', 'VERB'),
#  ('increases', 'NOUN', 'VERB'),
#  ('63-year-old', 'NOUN', 'ADJ'),
#  ('English', 'ADJ', 'NOUN'),
#  ('CoreStates', 'VERB', 'NOUN'),
#  ('account', 'VERB', 'NOUN'),
#  ('there', 'DET', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('open', 'VERB', 'ADJ'),
#  ('drink', 'VERB', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('cardiovascular', 'NOUN', 'ADJ'),
#  ('infectious', 'NOUN', 'ADJ'),
#  ('guarantee', 'VERB', 'NOUN'),
#  ('operating', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('half', 'DET', 'NOUN'),
#  ('espouse', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('one-third', 'NOUN', 'ADJ'),
#  ('finance', 'VERB', 'NOUN'),
#  ('59-year-old', 'NOUN', 'ADJ'),
#  ('heebie-jeebies', 'VERB', 'NOUN'),
#  ('much', 'ADV', 'ADJ'),
#  ('point', 'VERB', 'NOUN'),
#  ('audit', 'VERB', 'NOUN'),
#  ('stand', 'VERB', 'NOUN'),
#  ('display', 'NOUN', 'VERB'),
#  ('underline', 'NOUN', 'VERB'),
#  ('publishing', 'VERB', 'NOUN'),
#  ('all', 'DET', 'ADV'),
#  ('following', 'VERB', 'NOUN'),
#  ('round-trip', 'NOUN', 'ADJ'),
#  ('240-page', 'NOUN', 'ADJ'),
#  ('Next', 'NOUN', 'ADJ'),
#  ('launch', 'VERB', 'NOUN'),
#  ('capped', 'ADJ', 'VERB'),
#  ('Philippine', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NOUN'),
#  ('Spending', 'VERB', 'NOUN'),
#  ('nonresidential', 'NOUN', 'ADJ'),
#  ('off', 'PRT', 'ADJ'),
#  ('awaits', 'NOUN', 'VERB'),
#  ('point', 'NOUN', 'VERB'),
#  ('B-1B', 'ADJ', 'NOUN'),
#  ('out', 'PRT', 'ADP'),
#  ('half', 'NOUN', 'DET'),
#  ('earlier', 'ADV', 'ADJ'),
#  ('next', 'ADP', 'ADJ'),
#  ('Soviet', 'ADJ', 'NOUN'),
#  ('off', 'PRT', 'ADP'),
#  ('broadly', 'NOUN', 'ADV'),
#  ('emasculate', 'NOUN', 'VERB'),
#  ('swallow', 'NOUN', 'VERB'),
#  ('contrary', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NUM')]

# %% [markdown]
# #### Modification 4 -  using a regex tagger and unigram tagger as backoff tagger

# %%
unigramTagger1 = nltk.UnigramTagger(train_set)
patterns1 = [
    (r'[\w+]+ing$', 'VERB'),              # gerund
    (r'.*ed$', 'VERB'),               # past tense
    (r'.*es$', 'VERB'),               # 3rd singular present
    (r'.*\'s$', 'NOUN'),              # possessive nouns
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'\*T?\*?-[0-9]+$', 'X'),        # X
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'), # cardinal numbers
]
rule_based_tagger1 = nltk.RegexpTagger(patterns,backoff=unigramTagger1)

# %%
def VitterbiMod4(words,train_bag = taggedWords):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = df.loc['.', tag]
            else:
                transition_p = df.loc[state[-1], tag]
               
            emission = WordGivenTag(words[key], tag)
            emission_p = emission[0]/emission[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        state_max = rule_based_tagger1.tag([word])[0][1]
        
        if pmax > 0:
          if state_max != "X":
            state_max = T[p.index(pmax)]  
        state.append(state_max)
    return list(zip(words, state))

# %%
vitterbiMod4 = VitterbiMod4(untaggedWords)
check = [i for i, j in zip(vitterbiMod4, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbiMod4)
accuracy
# Out:
# 0.9494393907340808

# %%
# List of incorrect tags - (Word, predicted tag, actual tag)

incorrect_tagged_words = [(a[0],a[1],b[1]) for a,b in zip(vitterbiMod4,taggedWords) if a[1] != b[1]]
print(len(incorrect_tagged_words))
incorrect_tagged_words
# Out:
# 239
# [('book', 'NOUN', 'VERB'),
#  ('stocks', 'NOUN', 'ADV'),
#  ('up', 'PRT', 'ADP'),
#  ('over', 'ADP', 'PRT'),
#  ('mine', 'NOUN', 'ADJ'),
#  ('Palestinian', 'ADJ', 'NOUN'),
#  ('first', 'ADJ', 'ADV'),
#  ('third-largest', 'NOUN', 'ADJ'),
#  ('fifth-largest', 'NOUN', 'ADJ'),
#  ('Sit', 'NOUN', 'VERB'),
#  ('down', 'ADP', 'ADV'),
#  ('British', 'ADJ', 'NOUN'),
#  ('halt', 'NOUN', 'VERB'),
#  ('slides', 'NOUN', 'VERB'),
#  ('most', 'ADJ', 'ADV'),
#  ('athletic', 'NOUN', 'ADJ'),
#  ('to', 'PRT', 'ADJ'),
#  ('better', 'ADJ', 'ADV'),
#  ('attempt', 'VERB', 'NOUN'),
#  ('usurp', 'NOUN', 'VERB'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('administer', 'NOUN', 'VERB'),
#  ('applicable', 'NOUN', 'ADJ'),
#  ('Five', 'NOUN', 'NUM'),
#  ('Proper', 'NOUN', 'ADJ'),
#  ('English', 'NOUN', 'ADJ'),
#  ('highest-pitched', 'VERB', 'ADJ'),
#  ('as', 'ADP', 'ADV'),
#  ('62-year-old', 'NOUN', 'ADJ'),
#  ('executive', 'NOUN', 'ADJ'),
#  ('unsolicited', 'VERB', 'ADJ'),
#  ('bid', 'VERB', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('diversified', 'ADJ', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('impressive', 'NOUN', 'ADJ'),
#  ('issue', 'NOUN', 'VERB'),
#  ('29year', 'NOUN', 'ADJ'),
#  ('nine-month', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('ECONOMIC', 'NOUN', 'ADJ'),
#  ('APPEARS', 'NOUN', 'VERB'),
#  ('off', 'PRT', 'ADP'),
#  ('that', 'ADP', 'DET'),
#  ('U.S.-Japanese', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('up', 'ADV', 'ADP'),
#  ('past', 'ADJ', 'NOUN'),
#  ('senior', 'ADJ', 'NOUN'),
#  ('speculate', 'NOUN', 'VERB'),
#  ('yen-support', 'NOUN', 'ADJ'),
#  ('excess', 'ADJ', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('smiles', 'VERB', 'NOUN'),
#  ('rebound', 'VERB', 'NOUN'),
#  ('Left', 'NOUN', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('so', 'ADP', 'ADV'),
#  ('much', 'ADJ', 'ADV'),
#  ('preclinical', 'NOUN', 'ADJ'),
#  ('vague', 'NOUN', 'ADJ'),
#  ('mushy', 'NOUN', 'ADJ'),
#  ('that', 'DET', 'ADP'),
#  ('out', 'PRT', 'ADV'),
#  ('le', 'NOUN', 'DET'),
#  ('back', 'PRT', 'ADV'),
#  ('care', 'VERB', 'NOUN'),
#  ('care', 'VERB', 'NOUN'),
#  ('clear', 'ADJ', 'VERB'),
#  ('fuel', 'NOUN', 'VERB'),
#  ('84-year-old', 'NOUN', 'ADJ'),
#  ('amazingly', 'NOUN', 'ADV'),
#  ('individual', 'ADJ', 'NOUN'),
#  ('intelligent', 'NOUN', 'ADJ'),
#  ('insane', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('tailor-made', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('purhasing', 'VERB', 'NOUN'),
#  ('report', 'VERB', 'NOUN'),
#  ('movies', 'VERB', 'NOUN'),
#  ('marvelously', 'NOUN', 'ADV'),
#  ('loose', 'NOUN', 'ADJ'),
#  ('work', 'VERB', 'NOUN'),
#  ('force', 'VERB', 'NOUN'),
#  ('refer', 'NOUN', 'VERB'),
#  ('clouding', 'VERB', 'NOUN'),
#  ('about', 'ADP', 'ADV'),
#  ('up', 'ADV', 'PRT'),
#  ('solemn', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('intricate', 'NOUN', 'ADJ'),
#  ('faultlessly', 'NOUN', 'ADV'),
#  ('properties', 'VERB', 'NOUN'),
#  ('Indexing', 'VERB', 'NOUN'),
#  ('panic', 'NOUN', 'VERB'),
#  ('so', 'ADV', 'ADP'),
#  ('assistant', 'NOUN', 'ADJ'),
#  ('following', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('shown', 'NOUN', 'VERB'),
#  ('finest', 'NOUN', 'ADJ'),
#  ('defeats', 'NOUN', 'VERB'),
#  ('inkling', 'VERB', 'NOUN'),
#  ('underprivileged', 'VERB', 'ADJ'),
#  ('much', 'ADJ', 'ADV'),
#  ('savvier', 'NOUN', 'ADJ'),
#  ('much', 'ADV', 'ADJ'),
#  ('as', 'ADP', 'ADV'),
#  ('as', 'ADP', 'ADV'),
#  ('Above', 'NOUN', 'ADP'),
#  ('confused', 'ADJ', 'VERB'),
#  ('around', 'ADP', 'PRT'),
#  ('blinks', 'NOUN', 'VERB'),
#  ('bar', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('abortion-related', 'VERB', 'ADJ'),
#  ("'s", 'PRT', 'VERB'),
#  ('more', 'ADJ', 'ADV'),
#  ('further', 'ADJ', 'ADV'),
#  ('load', 'NOUN', 'VERB'),
#  ('up', 'ADV', 'PRT'),
#  ('improbable', 'NOUN', 'ADJ'),
#  ('high-rise', 'NOUN', 'ADJ'),
#  ('help', 'VERB', 'NOUN'),
#  ('plastic', 'ADJ', 'NOUN'),
#  ('non-biodegradable', 'NOUN', 'ADJ'),
#  ('over', 'ADP', 'PRT'),
#  ('seventh', 'NOUN', 'ADJ'),
#  ("'82", 'NOUN', 'NUM'),
#  ('American', 'ADJ', 'NOUN'),
#  ('closer', 'ADV', 'ADJ'),
#  ('unwilling', 'VERB', 'ADJ'),
#  ('index-fund', 'NOUN', 'ADJ'),
#  ('more', 'ADV', 'ADJ'),
#  ('own', 'ADJ', 'VERB'),
#  ('charge', 'NOUN', 'VERB'),
#  ('American', 'ADJ', 'NOUN'),
#  ('matters', 'NOUN', 'VERB'),
#  ('fine', 'NOUN', 'ADV'),
#  ('chief', 'NOUN', 'ADJ'),
#  ('wealthy', 'NOUN', 'ADJ'),
#  ('well-connected', 'VERB', 'ADJ'),
#  ('financing', 'VERB', 'NOUN'),
#  ('American', 'ADJ', 'NOUN'),
#  ('that', 'ADP', 'DET'),
#  ('cavernous', 'NOUN', 'ADJ'),
#  ('money-losing', 'NOUN', 'ADJ'),
#  ('benefits', 'NOUN', 'VERB'),
#  ('U.S.', 'NOUN', 'ADJ'),
#  ('close', 'VERB', 'NOUN'),
#  ('appeal', 'NOUN', 'VERB'),
#  ('burn', 'NOUN', 'VERB'),
#  ('cleaner-burning', 'NOUN', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('select', 'NOUN', 'VERB'),
#  ('net', 'ADJ', 'NOUN'),
#  ('unrestricted', 'VERB', 'ADJ'),
#  ('that', 'ADP', 'DET'),
#  ('firm', 'NOUN', 'ADJ'),
#  ('opening', 'VERB', 'NOUN'),
#  ('less', 'ADV', 'ADJ'),
#  ('higher', 'ADJ', 'ADV'),
#  ('trading', 'NOUN', 'VERB'),
#  ('1980s', 'NUM', 'NOUN'),
#  ('yellow', 'NOUN', 'ADJ'),
#  ('record', 'NOUN', 'ADJ'),
#  ('Four', 'NOUN', 'NUM'),
#  ('half', 'DET', 'NOUN'),
#  ('27-year', 'NOUN', 'ADJ'),
#  ('information-services', 'VERB', 'NOUN'),
#  ('Southeast', 'NOUN', 'ADJ'),
#  ('uses', 'VERB', 'NOUN'),
#  ('cancer-causing', 'NOUN', 'ADJ'),
#  ('post', 'VERB', 'NOUN'),
#  ('little', 'ADJ', 'ADV'),
#  ('more', 'ADJ', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('that', 'ADP', 'DET'),
#  ('uptick', 'NOUN', 'VERB'),
#  ('head', 'NOUN', 'ADJ'),
#  ('comments', 'NOUN', 'VERB'),
#  ('increases', 'NOUN', 'VERB'),
#  ('63-year-old', 'NOUN', 'ADJ'),
#  ('English', 'ADJ', 'NOUN'),
#  ('CoreStates', 'VERB', 'NOUN'),
#  ('account', 'VERB', 'NOUN'),
#  ('there', 'DET', 'ADV'),
#  ('what', 'PRON', 'DET'),
#  ('open', 'VERB', 'ADJ'),
#  ('drink', 'VERB', 'NOUN'),
#  ('up', 'ADV', 'ADP'),
#  ('cardiovascular', 'NOUN', 'ADJ'),
#  ('infectious', 'NOUN', 'ADJ'),
#  ('guarantee', 'VERB', 'NOUN'),
#  ('operating', 'NOUN', 'VERB'),
#  ('that', 'ADP', 'DET'),
#  ('half', 'DET', 'NOUN'),
#  ('espouse', 'NOUN', 'VERB'),
#  ('about', 'ADP', 'ADV'),
#  ('one-third', 'NOUN', 'ADJ'),
#  ('finance', 'VERB', 'NOUN'),
#  ('59-year-old', 'NOUN', 'ADJ'),
#  ('heebie-jeebies', 'VERB', 'NOUN'),
#  ('much', 'ADV', 'ADJ'),
#  ('point', 'VERB', 'NOUN'),
#  ('audit', 'VERB', 'NOUN'),
#  ('stand', 'VERB', 'NOUN'),
#  ('display', 'NOUN', 'VERB'),
#  ('underline', 'NOUN', 'VERB'),
#  ('publishing', 'VERB', 'NOUN'),
#  ('all', 'DET', 'ADV'),
#  ('following', 'VERB', 'NOUN'),
#  ('round-trip', 'NOUN', 'ADJ'),
#  ('240-page', 'NOUN', 'ADJ'),
#  ('Next', 'NOUN', 'ADJ'),
#  ('launch', 'VERB', 'NOUN'),
#  ('capped', 'ADJ', 'VERB'),
#  ('Philippine', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NOUN'),
#  ('Spending', 'VERB', 'NOUN'),
#  ('nonresidential', 'NOUN', 'ADJ'),
#  ('off', 'PRT', 'ADJ'),
#  ('awaits', 'NOUN', 'VERB'),
#  ('point', 'NOUN', 'VERB'),
#  ('B-1B', 'ADJ', 'NOUN'),
#  ('out', 'PRT', 'ADP'),
#  ('half', 'NOUN', 'DET'),
#  ('earlier', 'ADV', 'ADJ'),
#  ('next', 'ADP', 'ADJ'),
#  ('Soviet', 'ADJ', 'NOUN'),
#  ('off', 'PRT', 'ADP'),
#  ('broadly', 'NOUN', 'ADV'),
#  ('emasculate', 'NOUN', 'VERB'),
#  ('swallow', 'NOUN', 'VERB'),
#  ('contrary', 'NOUN', 'ADJ'),
#  ('the', 'DET', 'NUM')]

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
vitterbi = VanillaViterbi(untaggedWords)
check = [i for i, j in zip(vitterbi, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbi)
print("Accuracy of vanilla viterbi")
print(accuracy)

vitterbiMod = VitterbiMod(untaggedWords)
check = [i for i, j in zip(vitterbiMod, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbiMod)
print("Accuracy of viterbi Modification 1 (using transition probability for unknown words)")
print(accuracy)

vitterbiMod2 = VitterbiMod4(untaggedWords)
check = [i for i, j in zip(vitterbiMod2, taggedWords) if i == j] 
accuracy = len(check)/len(vitterbiMod2)
print("Accuracy of viterbi Modification 2 (using backoff tagger for unknown words)")
print(accuracy)
# Out:
# Accuracy of vanilla viterbi
# 0.9028982441294691
# Accuracy of viterbi Modification 1 (using transition probability for unknown words)
# 0.9331499894224666
# Accuracy of viterbi Modification 2 (using backoff tagger for unknown words)
# 0.9494393907340808

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %% [markdown]
# #### Preparing the evaluation data

# %%
a = open("Test_sentences.txt")
testSentences = a.readlines()
t1 = testSentences[0].strip()
t2 = testSentences[1].strip()
t3 = testSentences[2].strip()
words1 = nltk.word_tokenize(t1)
words2 = nltk.word_tokenize(t2)
words3 = nltk.word_tokenize(t3)

# %% [markdown]
# #### comparing vanilla and modified viterbi

# %%
testTags = VanillaViterbi(words1)
display("Vanilla")
display(testTags)
testTags = VitterbiMod4(words1)
display("Modified")
display(testTags)
# Out:
# 'Vanilla'
# [('Android', '.'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', '.'),
#  ('.', '.')]
# 'Modified'
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# Following are correctly identified by modified and incorrectly by vanilla viterbi: <br>
#
# 1. Android as NOUN
# 2. operatiing as NOUN
# 3. system as NOUN
# 4. Google as NOUN

# %%
testTags = VanillaViterbi(words2)
display("Vanilla")
display(testTags)
testTags = VitterbiMod4(words2)
display("Modified")
display(testTags)
# Out:
# 'Vanilla'
# [('Android', '.'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', '.'),
#  ('worldwide', '.'),
#  ('on', 'ADP'),
#  ('smartphones', '.'),
#  ('since', 'ADP'),
#  ('2011', '.'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', '.'),
#  ('.', '.')]
# 'Modified'
# [('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'VERB'),
#  ('since', 'ADP'),
#  ('2011', 'NUM'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('.', '.')]

# %% [markdown]
# Following are correctly identified by modified and incorrectly by vanilla viterbi: <br>
#
# 1. Android as NOUN
# 2. OS as NOUN
# 3. worldwide as NOUN
# 4. 2011 as NUM
# 5. 2018 as NUM

# %%
testTags = VanillaViterbi(words3)
display("Vanilla")
display(testTags)
testTags = VitterbiMod4(words3)
display("Modified")
display(testTags)
# Out:
# 'Vanilla'
# [('Google', '.'),
#  ('and', 'CONJ'),
#  ('Twitter', '.'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', '.'),
#  ('that', 'DET'),
#  ('gave', 'VERB'),
#  ('Google', '.'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', '.'),
#  ("'s", 'VERB'),
#  ('firehose', '.'),
#  ('.', '.')]
# 'Modified'
# [('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NUM'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# Following are correctly identified by modified and incorrectly by vanilla viterbi: <br>
#
# 1. Google as NOUN
# 2. Twitter as NOUN
# 3. 2015 as NUM
#
# "that" in the sentence has been incorrectly tagged as ADP by modified vitterbi algorithm
